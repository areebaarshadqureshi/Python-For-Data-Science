# %% [markdown]
# <a href="https://colab.research.google.com/github/areebaarshadqureshi/Python-For-Data-Science/blob/main/03-Nested-Loops-and-String-Manipulation/Lecture_03_Task_Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1 - Print the following pattern. Write a program to use for loop to print the following reverse number pattern.
#
# 5 4 3 2 1
#
# 4 3 2 1
#
# 3 2 1
#
# 2 1
#
# 1

# %%
n=int(input("Enter no of rows:"))

for i in range(n,0,-1):
  for j in range(i,0,-1):
    print(j,end="")
  print()
# Out:
# Enter no of rows:5
# 54321
# 4321
# 321
# 21
# 1

# %% [markdown]
# Problem 2: Print the following pattern.
# <pre>
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
m,n=map(int,input("Enter two values:").split(","))
for i in range(1,n+1):
  for j in range(1,i+1):
    print("*",end=" ")
  print()
for k in range(m,0,-1):
  for l in range(k,0,-1):
    print("*",end=" ")
  print()
# Out:
# Enter two values:5,4
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# Problem 3:Write a program to pring the following pattern
# <pre>
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *

# %%
m=int(input("Enter two values:"))
j=0
for i in range(1,m+1):
   for j in range(1,m-i+1):
      print(" ",end=" ")
   for k in range(1,i+1):
        print("*",end=" ")
   for l in range(2,i+1):
        print("*",end=" ")


   print()
# Out:
# Enter two values:5
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *

# %% [markdown]
# Problem 4:Write a program to print the following pattern
# 1
#
# 2 1
#
# 3 2 1
#
# 4 3 2 1
#
# 5 4 3 2 1

# %%
m=int(input("Enter any number:"))
for i in range(1,m+1):
  for j in range (1,i+1):
    print(i-j+1,end=" ")
  print()
# Out:
# Enter any number:5
# 1
# 2 1
# 3 2 1
# 4 3 2 1
# 5 4 3 2 1

# %% [markdown]
# Problem 6: The natural logarithm can be approximated by the following series.

# %%
n= int(input("Enter any number:"))
sum=0.0

for i in range(1,i+1):
  if i==1:
   sum+=(n-1/n)**i
  else:
    sum+=(1/2)*((n-1/n)**i)
print(f"The sum of first {n}th series: {sum:.2f}")
# Out:
# Enter any number:4
# The sum of first 4th series: 10.78

# %% [markdown]
# Problem 7 - Find the sum of the series upto n terms.
# Write a program to calculate the sum of series up to n term. For example, if n =5 the series will become 2 + 22 + 222 + 2222 + 22222 = 24690. Take the user input and then calculate. And the output style should match which is given in the example.
#
# Example 1:

# %%
n=int(input("Enter any number:"))
sum=0
for i in range(1,1+n):
  s="2"*i
  sum+=int(s)
print(f"Sum is:{sum}")
# Out:
# Enter any number:5
# Sum is:24690

# %% [markdown]
# Problem 8: Write a program to print all the unique combinations of 1,2,3 and 4

# %%
n=int(input("Enter any number:"))
m=2**n
# Out:
# Enter any number:3

# %% [markdown]
# Problem 9: Write a program that will take a decimal number as input and prints out the binary equivalent of the number

# %%
n=int(input("Enter any number in decimal:"))

b=bin(n)[2:]

print(f"Binary is:{b}")
# Out:
# Enter any number in decimal:2
# Binary is:10

# %% [markdown]
# Problem 10: Write a program that will take 2 numbers as input and prints the LCM and HCF of those 2 numbers

# %%
m, n = map(int, input("Enter any two numbers: ").split(","))

orig_m = m
orig_n = n

l1 = []
l2 = []

i = 2
while m > 1:
    if m % i == 0:
        m //= i
        l1.append(i)
    else:
        i += 1

i = 2
while n > 1:
    if n % i == 0:
        n //= i
        l2.append(i)
    else:
        i += 1

print(f"Prime factors of {orig_m} are: {l1}")
print(f"Prime factors of {orig_n} are: {l2}")

l3=[]
for i in range(len(l1)):
  if l1[i] in l2 :
    l3.append(l1[i])
    l2.remove(l1[i])
print(f"The HCF of {orig_m} and {orig_n} is: {l3}")
# Out:
# Enter any two numbers: 408,1032
# Prime factors of 408 are: [2, 2, 2, 3, 17]
# Prime factors of 1032 are: [2, 2, 2, 3, 43]
# The HCF of 408 and 1032 is: [2, 2, 2, 3]

# %% [markdown]
# Problem 11: Create Short Form from initial character
# Given a string create short form ofthe string from Initial character. Short form should be capitalised.
#
# Example:
#
# Input:
#
# Data science mentorship program
# Output:
#
# DSMP

# %%
n=input("Enter any string:")
s=n.title()
print(s)

for i in range(len(s)):
  if i==0 or s[i-1]==" ":
    print(s[i])
# Out:
# Enter any string:data science mentorship program
# Data Science Mentorship Program
# D
# S
# M
# P

# %% [markdown]
# Problem 12: Append second string in the middle of first string

# %%
m,n=map(str,input("Enter nay two strings:").split(" "))
middle=m[len(m)//2]


for i in range(len(m)):
  if m[i]==middle:
    m=m[:i]+n+m[i:]
print(m)
# Out:
# Enter nay two strings:campusx data
# camdatapusx

# %% [markdown]
# Problem 13:Given string contains a combination of the lower and upper case letters. Write a program to arrange the characters of a string so that all lowercase letters should come first.
# Given:
#
# str1 = PyNaTive
#
# Expected Output:
#
# yaivePNT

# %%
s=input("Enter nay string:")

for i in range(len(s)):
  if s[i]>='a' and s[i]<='z':
     s=s[i]+s[:i]+s[i+1:]

print(s)
# Out:
# Enter nay string:PyNaTive
# eviayPNT

# %% [markdown]
# Problem 14:Take a alphanumeric string input and print the sum and average of the digits that appear in the string, ignoring all other characters.
# Input:
#
# hel123O4every093
#
# Output:
#
# Sum: 22
# Avg: 2.75

# %%
n=input("Enter any string:")
sum=0
count=0
for i in range(len(n)):
  if n[i] >='0' and n[i] <='9':
    sum+=int(n[i])
    count+=1
print(f"Sum:{sum}")
print(f"Avg:{sum/count:.2f}")
# Out:
# Enter any stirng:hel12304every093
# Sum:22
# Avg:2.75

# %% [markdown]
# Problem 15: Removal of all characters from a string except integers
# Given:
#
# str1 = 'I am 25 years and 10 months old'
# Expected Output:
#
# 2510

# %%
n=input("Enter any string:")
str1=""
for i in range(len(n)):
  if n[i]>="0" and n[i]<="9":
       str1=str1+n[i]
print(str1)
# Out:
# Enter any string:I am 25 years and 10 months old
# 2510

# %% [markdown]
# Problem 16: Check whether the string is Symmetrical.
# Statement: Given a string. the task is to check if the string is symmetrical or not. A string is said to be symmetrical if both the halves of the string are the same.
#
# Example 1:
#
# Input
#
# khokho
# Output
#
# The entered string is symmetrical

# %%
n=input("Enter any string:")
middle=len(n)//2

for i in range(middle):
  if n[i]!=n[middle+i]:
    print("The entered string is not symmetrical")
    break
else:
  print("The entered string is symmetrical")
# Out:
# Enter any string:lololo
# The entered string is not symmetrical

# %% [markdown]
# Problem 17: Reverse words in a given String
# Statement: We are given a string and we need to reverse words of a given string.
#
# Example 1:
#
# Input:
#
# geeks quiz practice code
# Output:
#
# code practice quiz geeks
# Example 2:
#
# Input:
#
# my name is laxmi
# Output:
#
# laxmi is name my

# %%
n=input("Enter any string:")
s=""
l=""
for i in range(len(n)-1,-1,-1):
  s=s+n[i]
  if n[i]==" ":
    for j in range(len(s)-1,-1,-1):
      l=l+s[j]
    s=""
#Handle first word
l+=" "
for j in range(len(s)-1, -1, -1):
    l += s[j]

print(l)
# Out:
# Enter any string:my name is laxmi
#  laxmi is name my

# %% [markdown]
# Problem 18: Find uncommon words from two Strings.
# Statement: Given two sentences as strings A and B. The task is to return a list of all uncommon words. A word is uncommon if it appears exactly once in any one of the sentences, and does not appear in the other sentence. Note: A sentence is a string of space-separated words. Each word consists only of lowercase letters.
#
# Example 1:
#
# Input:
#
# A = "apple banana mango"
# B = "banana fruits mango"
# Output:
#
# ['apple', 'fruits']

# %%
m=input("Enter any string:")
n=input("Enter any string:")
l1=m.split()
l2=n.split()
print(l1)
print(l2)
l3=[]
for i in l1:
  if i in l2:
     l2.remove(i)
  else:
    l3.append(i)
l3.extend(l2)
print(l3)
# Out:
# Enter any string:apple banana mango
# Enter any string:banana fruits mango
# ['apple', 'banana', 'mango']
# ['banana', 'fruits', 'mango']
# ['apple', 'fruits']

# %% [markdown]
# Problem 19: Word location in String.
# Statement: Find a location of a word in a given sentence.
#
# Example 1:
#
# Input:
#
# Sentence: We can learn data science through campusx mentorship program.
#
# word: campusx
# Output:
#
# Location of the word is 7.
# Note- Don't use index/find functions

# %%
sen=input("Enter any sentence:")
word=input("Enter any word:")
i=0
count=1

while True:
  if sen[i]==" ":
    count+=1
  if sen[i]==word[0]:
     flag=1
     for j in range(0,len(word)):
      if sen[i+j]!=word[j]:
        flag=0
        break
     else:
        n=count
        flag = 1
        break
  i+=1
if flag==1:
 print(f"Location of {word} is: {n}")
else:
 print("Not found")
# Out:
# Enter any sentence:We can learn data science through campusx mentorship program.
# Enter any word:program
# Location of program is: 9

# %% [markdown]
# Problem 20: Write a program that can remove all the duplicate characters from a string. User will provide the input.

# %%
n=input("Enter any string:")
s=""
n=n.lower()
for i in n:
  if i not in s:
      s+=i
print(s.capitalize())
# Out:
# Enter any string:Areeba
# Areb
