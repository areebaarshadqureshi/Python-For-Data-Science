# %% [markdown]
# <a href="https://colab.research.google.com/github/areebaarshadqureshi/Data-Science-Journey-CampusX/blob/main/01-Python/05-Tuples-Sets-and-Dictionaries/Tuples_Sets_Dict_Tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Tuples

# %% [markdown]
# Q1: Join Tuples if similar initial element
# While working with Python tuples, we can have a problem in which we need to perform concatenation of records from the similarity of initial element. This problem can have applications in data domains such as Data Science.
#
# For eg.
#
# Input  : test_list = [(5, 6), (5, 7), (5, 8), (6, 10), (7, 13)]
# Output : [(5, 6, 7, 8), (6, 10), (7, 13)]

# %%
t = [(5, 6), (5, 7), (5, 8), (6, 10),(6,9) ,(7, 13)]
result = []

for a, b in t:
    for i in result:
        if i[0] == a:
           i.append(b)
           break
    else:
        result.append([a, b])

result = [tuple(i) for i in result]

print(result)
# Out:
# [(5, 6, 7, 8), (6, 10, 9), (7, 13)]

# %% [markdown]
# Q2: Multiply Adjacent elements (both side) and take sum of right and lest side multiplication result.

# %%
t=(1, 5, 7, 8, 10)
t1=[]
for i in range(len(t)):
  if i==0:
     t1.append(t[i]*t[i+1])
  elif i==len(t)-1:
    t1.append(t[i-1]*t[i]+t[i]*t[i-1])
  else:
     t1.append(t[i]*t[i-1]+t[i]*t[i+1])
print(tuple(t1))
# Out:
# (5, 40, 91, 136, 160)

# %% [markdown]
# 3: Check is tuples are same or not?
# Two tuples would be same if both tuples have same element at same index

# %%
t1 = (1,2,3,0)
t2 = (1,2,3,0,4)
if len(t1) != len(t2):
    print(f"{t1} and {t2} are not same")
else:
  flag=0
  for i in range(len(t1)):
    if t1[i]!=t2[i]:
      flag=0
      break
    else:
      flag=1
    if flag==1:
     print(f"{t1} and {t2} are same")
    else:
     print(f"{t1} and {t2} are not same")
# Out:
# (1, 2, 3, 0) and (1, 2, 3, 0, 4) are not same

# %% [markdown]
# Q4: Count no of tuples, list and set from a list

# %%
list1 = [{'hi', 'bye'},{'Geeks', 'forGeeks'},('a', 'b'),['hi', 'bye'],['a', 'b']]
l=0
s=0
t=0

for i in list1:
  if type(i)==list:
    l+=1
  if type(i)==tuple:
    t+=1
  if type(i)==set:
    s+=1

print(f"List count is {l}")
print(f"Tuple count is {t}")
print(f"Set count is {s}")
# Out:
# List count is 2
# Tuple count is 1
# Set count is 2

# %% [markdown]
# Shortlist Students for a Job role
# Ask user to input students record and store in tuples for each record. Then Ask user to input three things he wants in the candidate- Primary Skill, Higher Education, Year of Graduation.
#
# Show every students record in form of tuples if matches all required criteria.
#
# It is assumed that there will be only one primry skill.
#
# If no such candidate found, print No such candidate

# %%
n= int(input("How many records you want to enter:"))
name=[]
skill=[]
h_edu=[]
y_g=[]
for i in range(n):
  print("\n")
  print(f"Enter Details of student-{i+1}")
  a=input("Enter student Name:")
  name.append(a)
  b=input("Enter student Primary Skill:")
  skill.append(b)
  c=input("Enter student Higher Education:")
  h_edu.append(c)
  e=input("Enter student Year of Graduation:")
  y_g.append(e)

print("Enter Job Role Requirement")
a=input("Enter student Skill:")
b=input("Enter student Higher Education:")
c=input("Enter Year of Graduation:")

for i in range(len(name)):
  if a==skill[i] and b==h_edu[i] and c==y_g[i]:
    print(tuple([name[i],skill[i],h_edu[i],y_g[i]]))
  else:
    print("No such candidate")
# Out:
# How many records you want to enter:1
#
#
# Enter Details of student-1
# Enter student Name:Areeba
# Enter student Primary Skill:Python
# Enter student Higher Education:BSCS
# Enter student Year of Graduation:2026
# Enter Job Role Requirement
# Enter student Skill:Python
# Enter student Higher Education:BSCS
# Enter Year of Graduation:2026
# ('Areeba', 'Python', 'BSCS', '2026')

# %% [markdown]
# ##Set

# %% [markdown]
# ###`Q1:` Write a program to find set of common elements in three lists using sets.
# ```
# Input : ar1 = [1, 5, 10, 20, 40, 80]
#         ar2 = [6, 7, 20, 80, 100]
#         ar3 = [3, 4, 15, 20, 30, 70, 80, 120]
#
# Output : [80, 20]
# ```

# %%
ar1 = [1, 5, 10, 20, 40, 80]
ar2 = [6, 7, 20, 80, 100]
ar3 = [3, 4, 15, 20, 30, 70, 80, 12]
arr={}
ar1=set(ar1)
ar2=set(ar2)
ar3=set(ar3)

ar1.intersection_update(ar2)
ar1.intersection_update(ar3)
print(list(ar1))
# Out:
# [80, 20]

# %% [markdown]
# ###`Q2:` Write a program to count unique number of vowels using sets in a given string. Lowercase and upercase vowels will be taken as different.
#
# `Input:`
# ```
# Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"
# ```
# `Output:`
# ```
# No of unique vowels-6
# ```

# %%
Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"
s={}
s=set(Str1)
vowels={'a','e','i','o','u','A','E','I','O',"U"}

s.intersection_update(vowels)
print(f"No of unique vowels-{len(s)}")
# Out:
# No of unique vowels-6

# %% [markdown]
# ### `Q3:` Write a program to Check if a given string is binary string of or not.
#
# A string is said to be binary if it's consists of only two unique characters.
#
# Take string input from user.
#
# ```
# Input: str = "01010101010"
# Output: Yes
#
# Input: str = "1222211"
# Output: Yes
#
# Input: str = "Campusx"
# Output: No
# ```

# %%
n=input("Enter any string:")
n=set(n)
s1={'0','1'}
n.intersection_update(s1)
if len(n)==len(s1):
  print("yes")
else:
  print("No")
# Out:
# Enter any string:10101010101
# yes

# %% [markdown]
# ### `Q4`: find union of n arrays.
#
# **Example 1:**
#
# Input:
# ```bash
# [[1, 2, 2, 4, 3, 6],
#  [5, 1, 3, 4],
#  [9, 5, 7, 1],
#  [2, 4, 1, 3]]
# ```
#
# Output:
#
# ```bash
# [1, 2, 3, 4, 5, 6, 7, 9]
# ```

# %%
n=[[1, 2, 2, 4, 3, 6],
 [5, 1, 3, 4],
 [9, 5, 7, 1],
 [2, 4, 1, 3]]
n1=[]

for i in range(len(n)):
  n1.append(set(n[i]))
print(n1)
merge=set.union(*n1)
print(list(merge))
# Out:
# [{1, 2, 3, 4, 6}, {1, 3, 4, 5}, {9, 5, 1, 7}, {1, 2, 3, 4}]
# [1, 2, 3, 4, 5, 6, 7, 9]

# %% [markdown]
# ### `Q5`: Intersection of two lists. Intersection of two list means we need to take all those elements which are common to both of the initial lists and store them into another list. Only use using **list-comprehension**.
#
# **Example 1:**
#
# Input:
# ```bash
# lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
# lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}
# ```
#
# Output:
# ```bash
# [9, 10, 4, 5]
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
# lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}
# ```
#
# Output:
# ```bash
# [9, 11, 26, 28]
# ```

# %%
# lst1=set()
# lst2=set()

# while True:
#   n=int(input("Enter any number:"))
#   lst1.add(n)
#   i=int(input("Enter 1 to continue:"))
#   if i==0:
#     break
# while True:
#   n=int(input("Enter any number:"))
#   lst2.add(n)
#   i=int(input("Enter 1 to continue:"))
#   if i==0:
#     break
lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}
lst1=set(lst1)
lst2=set(lst2)
lst1.intersection_update(lst2)
print(list(lst1))
# Out:
# [9, 26, 11, 28]

# %% [markdown]
# ### `Q1`: Key with maximum unique values
#
# Given a dictionary with values list, extract key whose value has most unique values.
#
# **Example 1:**
#
# Input:
#
# ```bash
# test_dict = {"CampusX" : [5, 7, 9, 4, 0], "is" : [6, 7, 4, 3, 3], "Best" : [9, 9, 6, 5, 5]}
# ```
#
# Output:
# ```bash
# CampusX
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_dict = {"CampusX" : [5, 7, 7, 7, 7], "is" : [6, 7, 7, 7], "Best" : [9, 9, 6, 5, 5]}
# ```
#
# Output:
# ```bash
# Best
# ```

# %%
# test_dict = {}
# n = int(input("How many keys? "))

# for _ in range(n):
#     key = input("Enter key: ")
#     values = list(map(int, input("Enter list of values separated by space: ").split(",")))
#     test_dict[key] = values

# print(test_dict)
test_dict = {"CampusX" : [5, 7, 9, 4, 0], "is" : [6, 7, 4, 3, 3], "Best" : [9, 9, 6, 5, 5]}

l=[]
count=0
for i,j in test_dict.items():
  if len(set(j)) >count:
    count=len(set(j))
    l=i
print(l)
# Out:
# CampusX

# %% [markdown]
# ### `Q2`: Replace words from Dictionary. Given String, replace it’s words from lookup dictionary.
#
# **Example 1:**
#
# Input:
#
# ```bash
# test_str = 'CampusX best for DS students.'
# repl_dict = {"best" : "is the best channel", "DS" : "Data-Science"}
# ```
#
# Output:
#
# ```bash
# CampusX is the best channel for Data-Science students.
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_str = 'CampusX best for DS students.'
# repl_dict = {"good" : "is the best channel", "ds" : "Data-Science"}
# ```
#
# Output:
# ```bash
# CampusX best for DS students.
# ```

# %%
test_str = 'CampusX best for DS students.'
repl_dict = {"best" : "is the best channel", "DS" : "Data-Science"}
test=""
for i in repl_dict.keys():
   for j in test_str.split():
    if i==j:
      test_str=test_str.replace(j,repl_dict[i])
print(test_str)
# Out:
# CampusX is the best channel for Data-Science students.

# %% [markdown]
# ### `Q3`: Convert List to List of dictionaries. Given list values and keys list, convert these values to key value pairs in form of list of dictionaries.
#
# **Example 1:**
#
# Input:
# ```bash
# test_list = ["DataScience", 3, "is", 8]
# key_list = ["name", "id"]
# ```
#
# Output:
#
# ```bash
# [{'name': 'DataScience', 'id': 3}, {'name': 'is', 'id': 8}]
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_list = ["CampusX", 10]
# key_list = ["name", "id"]
# ```
#
# Output:
#
# ```bash
# [{'name': 'CampusX', 'id': 10}]
# ```

# %%
test_list = ["DataScience", 3, "is", 8]
key_list = ["name", "id"]

output = []
for i in range(0, len(test_list), len(key_list)):
    group = test_list[i:i+len(key_list)]
    d = {k: v for k, v in zip(key_list, group)}
    output.append(d)

print(output)
# Out:
# [{'name': 'DataScience', 'id': 3}, {'name': 'is', 'id': 8}]

# %% [markdown]
# ### `Q4`: Convert a list of Tuples into Dictionary.
#
# **Example 1:**
#
# Input:
# ```bash
# [("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
# ```
#
# Output:
# ```bash
# {'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# [('A', 1), ('B', 2), ('C', 3)]
# ```
#
# Output:
# ```bash
# {'A': [1], 'B': [2], 'C': [3]}
# ```

# %%
n=[("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]


{i:[j] for i,j in n}
# Out:
# {'akash': [10],
#  'gaurav': [12],
#  'anand': [14],
#  'suraj': [20],
#  'akhil': [25],
#  'ashish': [30]}

# %% [markdown]
# ### `Q5`: Sort Dictionary key and values List.
#
# **Example 1:**
#
# Input:
#
# ```bash
# {'c': [3], 'b': [12, 10], 'a': [19, 4]}
# ```
#
# Output:
#
# ```bash
# {'a': [4, 19], 'b': [10, 12], 'c': [3]}
# ```
#
# **Example 2:**
#
# Input:
#
# ```bash
# {'c': [10, 34, 3]}
# ```
#
# Output:
#
# ```bash
# {'c': [3, 10, 34]}
# ```

# %%
d={'c': [3], 'b': [12, 10], 'a': [19, 4]}



{i:sorted(d[i]) for i in sorted(d.keys())}
# Out:
# {'a': [4, 19], 'b': [10, 12], 'c': [3]}
