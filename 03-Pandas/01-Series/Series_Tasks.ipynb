# %% [markdown]
# <a href="https://colab.research.google.com/github/areebaarshadqureshi/Data-Science-Journey-CampusX/blob/main/07-Pandas/01-Series/Series_Tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
import pandas as pd
import numpy as np
mv=pd.Series([])
mv.empty
# Out:
# True

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
s1=pd.Series(np.random.randint(1,10,size=10),name="Series1")
s2=pd.Series(np.random.randint(1,20,size=10),name="Series2")
print(s1+s2,end=" ")
print(s1-s2,end=" ")
print(s1*s2,end=" ")
print(s1/s2,end=" ")
# Out:
# 0    19
# 1     7
# 2    17
# 3    13
# 4     3
# 5    21
# 6    14
# 7     6
# 8    12
# 9    12
# dtype: int64 0    -5
# 1     1
# 2    -1
# 3     1
# 4     1
# 5    -3
# 6     2
# 7     0
# 8   -10
# 9    -2
# dtype: int64 0     84
# 1     12
# 2     72
# 3     42
# 4      2
# 5    108
# 6     48
# 7      9
# 8     11
# 9     35
# dtype: int64 0    0.583333
# 1    1.333333
# 2    0.888889
# 3    1.166667
# 4    2.000000
# 5    0.750000
# 6    1.333333
# 7    1.000000
# 8    0.090909
# 9    0.714286
# dtype: float64

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
s1=pd.Series([2, 4, 6, 8, 10])
s2=pd.Series([1, 3, 5, 7, 10])
print(s1==s2)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ###`Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
def func(s):
  s=pd.to_numeric(s,errors='coerce')
  return s
series = pd.Series([1,2,'Python', 2.0, True, 100])
func(series)
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
df=pd.read_csv('/content/batsman_runs_series.csv').squeeze()
df
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
df.sort_values(by="batsman_run",ascending=False).head(10)
# Out:
#              batter  batsman_run
# 569         V Kohli         6634
# 462        S Dhawan         6244
# 130       DA Warner         5883
# 430       RG Sharma         5881
# 493        SK Raina         5536
# 27   AB de Villiers         5181
# 108        CH Gayle         4997
# 339        MS Dhoni         4978
# 452      RV Uthappa         4954
# 256      KD Karthik         4377

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
df[df.batsman_run>3000].size
# Out:
# 40

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?

# %%
m=df.batsman_run.mean()
df[df.batsman_run>m].size
# Out:
# 256

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %% [markdown]
# ###`Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     ii. Item price is given in $, so convert it to rupees without currency symbol.
#     iii. Make data type of newly made series as float.
#     iv. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
df=pd.read_csv('/content/items.csv',index_col='item_name').squeeze()

df
# Out:
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98
#                                           ...
# Steak Burrito                            $11.75
# Steak Burrito                            $11.75
# Chicken Salad Bowl                       $11.25
# Chicken Salad Bowl                        $8.75
# Chicken Salad Bowl                        $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df.isnull().sum()
# Out:
# np.int64(50)

# %%
num=df.str.replace('$','')
num=num.astype(float)
num=num*280
num=num.fillna(num.mean())

# %% [markdown]
# ###`Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
num.mean()
# Out:
# np.float64(2089.6488188976377)

# %%
new=np.array(num)
n1=np.percentile(new,30)
n2=np.percentile(new,6)
print(n1,n2)
# Out:
# 1246.0 350.0

# %%
num.plot(kind='hist',bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
num[num.between(1000,2000)].size
# Out:
# 553
